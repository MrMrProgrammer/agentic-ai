# %% [markdown]
# # 🤖 آموزش اتصال به OpenAI API
#
# در این نوت‌بوک یاد می‌گیریم چطور به API اوپن‌ای متصل شویم و اولین درخواست خود را ارسال کنیم.
#
# ---

# %% [markdown]
# ## 📌 مرحله ۱ — دریافت API Key
#
# برای استفاده از OpenAI API به یک **API Key** نیاز داری. مراحل دریافت:
#
# 1. به سایت [https://platform.openai.com/home](https://platform.openai.com/home) برو
# 2. ثبت‌نام کن یا وارد حساب کاربری‌ات شو
# 3. از منوی بالا سمت راست روی **API Keys** کلیک کن
# 4. روی **Create new secret key** کلیک کن
# 5. کلید را کپی و در جای امنی ذخیره کن (بعد از بستن پنجره دیگر نمایش داده نمی‌شود)
#
# > ⚠️ **مهم:** API Key را هرگز در کد عمومی یا گیت‌هاب قرار نده!

# %% [markdown]
# ## 💳 مرحله ۲ — خرید اعتبار (برای کاربران ایران)
#
# از ایران نمی‌توان مستقیم به سرویس‌های پرداخت OpenAI دسترسی داشت. چند راه‌حل:
#
# ### روش اول — Numberland
# خرید API Credit از طریق واسطه ایرانی:
#
# 🔗 [https://numberland.ir/?ref=204551](https://numberland.ir/?ref=204551)
#
# ### روش دوم — IraniCard
#
# 🔗 [https://panel.iranicard.ir/login?redirect=%2Fdashboard%3FreferralCode%3D53928383](https://panel.iranicard.ir/login?redirect=%2Fdashboard%3FreferralCode%3D53928383)
#
# ---

# %% [markdown]
# ## 🇮🇷 مرحله ۳ — استفاده از Endpoint ایرانی (اختیاری)
#
# اگر از ایران هستی و نمی‌خوای درگیر تحریم‌ها و سرعت پایین شوی، می‌توانی از **endpoint ایرانی GapGPT** استفاده کنی:
#
# 🔗 [https://gapgpt.app/platform-v2/](https://gapgpt.app/platform-v2/)
#
# این endpoint با همان کتابخانه `openai` کار می‌کند، فقط `base_url` را تغییر می‌دهی.
#
# مزایا:
# - سرعت بهتر از ایران
# - بدون نیاز به VPN
# - سازگار با تمام مدل‌های OpenAI
#
# ---

# %% [markdown]
# ## 📦 مرحله ۴ — نصب کتابخانه

# %%
# !pip install openai

# %% [markdown]
# ## 🔑 مرحله ۵ — تنظیم کلید API (روش مستقیم)
#
# در این روش کلید را مستقیماً در کد قرار می‌دهیم.
#
# > ⚠️ این روش فقط برای تست محلی مناسب است. در پروژه‌های واقعی از متغیر محیطی استفاده کن (مرحله بعد).

# %%
from openai import OpenAI

# ─── روش ۱: اتصال مستقیم به سرور OpenAI ───────────────────────────
client = OpenAI(
    api_key="sk-proj-...",   # <-- کلید خود را اینجا بگذار
)

print("✅ اتصال مستقیم به OpenAI آماده است")
# Out:
# ✅ اتصال مستقیم به OpenAI آماده است

# %% [markdown]
# ## 🚀 مرحله ۶ — اولین درخواست

# %%
# ارسال یک پیام ساده به مدل
response = client.chat.completions.create(
    model="gpt-4o-mini",   # می‌توانی مدل را عوض کنی: gpt-4o, gpt-3.5-turbo, ...
    messages=[
        {"role": "system", "content": "تو یک دستیار مفید هستی که به فارسی پاسخ می‌دهی."},
        {"role": "user",   "content": "پایتخت ایران کجاست؟"}
    ]
)

# نمایش پاسخ
print(response.choices[0].message.content)

# %%
response.choices[0].message.content

# %% [markdown]
# ### سرویس ایرانی

# %% [markdown]
# 🔗 [https://gapgpt.app/platform-v2/](https://gapgpt.app/platform-v2/)

# %%
from openai import OpenAI

# ─── روش ۲: استفاده از endpoint ایرانی GapGPT ─────────────────────
client = OpenAI()

print("✅ اتصال از طریق endpoint ایرانی آماده است")
# Out:
# ✅ اتصال از طریق endpoint ایرانی آماده است

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "user", "content": "سلام، فقط بگو اتصال موفق بود."}
    ],
)

print(response.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 response = client.chat.completions.create(
#       2     model="gpt-4o-mini",
#       3     messages=[
#       4         {"role": "user", "content": "سلام، فقط بگو اتصال موفق بود."}
#
# File ~/Programming/Projects/agentic-ai/venv/lib/python3.13/site-packages/openai/_utils/_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# ...

# %%
# ارسال یک پیام ساده به مدل
response = client.chat.completions.create(
    model="claude-sonnet-4-6",   # می‌توانی مدل را عوض کنی: gpt-4o, gpt-3.5-turbo, ...
    messages=[
        {"role": "system", "content": "تو یک دستیار مفید هستی که به فارسی پاسخ می‌دهی."},
        {"role": "user",   "content": "پایتخت ایران کجاست؟"}
    ]
)

# نمایش پاسخ
print(response.choices[0].message.content)

# %% [markdown]
# ## 📊 مرحله ۷ — بررسی مصرف توکن

# %%
# اطلاعات مصرف توکن
usage = response.usage
print(f"توکن‌های ورودی  : {usage.prompt_tokens}")
print(f"توکن‌های خروجی : {usage.completion_tokens}")
print(f"مجموع توکن‌ها  : {usage.total_tokens}")

# %% [markdown]
# ---
#
# ## ⏭️ مرحله بعدی
#
# در نوت‌بوک بعدی یاد می‌گیریم چطور API Key را از **فایل `.env`** بخوانیم تا امنیت بیشتری داشته باشیم:
#
# ```python
# from dotenv import load_dotenv
# import os
#
# load_dotenv()  # فایل .env را لود می‌کند
# api_key = os.getenv("OPENAI_API_KEY")
# ```
#
# این روش استاندارد توسعه حرفه‌ای است! 🎯
