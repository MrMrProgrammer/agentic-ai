# %% [markdown]
# # Agentic AI - Reflection in a Research Agent
#
#
# **Source:** [DeepLearning.AI - Agentic AI Course](https://www.deeplearning.ai/courses/agentic-ai/)
# **Modified by:** [Alireza Akhavan](https://github.com/Alireza-Akhavan/Agentic_AI)
#
# In this notbook, you’ll implement a simple **[agentic](https://class.vision/blog/ai-agents/) workflow** designed to simulate reflective thinking in a writing task. This is one building block of a more complex research agent that will be constructed throughout the course.
#
# ### 📘 Objective
#
# Build a three-step workflow where an [LLM](https://class.vision/blog/llm-%D9%85%D8%AF%D9%84-%D8%B2%D8%A8%D8%A7%D9%86%DB%8C/) writes an essay draft, critiques it, and rewrites it. The focus of the lab is not on the content quality of the essay, but rather on how you orchestrate the **calls to the LLM** and pass intermediate results between steps.
#
# ### 🛠️ What You’ll Build
#
# * **Step 1 – Drafting:** Call the LLM to generate an initial draft of an essay based on a simple prompt.
# * **Step 2 – Reflection:** Reflect on the draft using a reasoning step. (Optionally, this can be done with a different model.)
# * **Step 3 – Revision:** Apply the feedback from the reflection to generate a revised version of the essay.

# %% [markdown]
# ## ⚙️ Loading Essentials
#
# Before interacting with the language models, we initialize the `aisuite` client. This setup loads environment variables (e.g., API keys) from a `.env` file to securely authenticate with backend services. The `ai.Client()` instance will be used to make all model calls throughout this workflow.

# %%
import aisuite as ai

client = ai.Client()

# %% [markdown]
# ### 📝 `generate_draft` Function
#
# **Objective**:
# Write a function called `generate_draft` that takes in a string prompt and uses a language model to generate a complete draft essay.
#
# **Inputs**:
#
# * `prompt` (str): The essay question or writing prompt.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-5.1"`.
#
# **Output**:
#
# * A string representing the full draft of the essay.

# %%
def generate_draft(prompt: str, model: str = "openai:gpt-5.1") -> str:
    instruction = f"""
    Write a well-structured draft essay in response to the following prompt.
    The draft should include an introduction, body, and conclusion.

    Prompt:
    {prompt}
    """

    response = client.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": instruction}],
        temperature=1.0,
    )
    return response.choices[0].message.content

# %% [markdown]
# ### 🔍 `reflect_on_draft` Function
#
# **Objective**:
# Write a function called `reflect_on_draft` that takes a previously generated essay draft and uses a language model to provide constructive feedback.
#
# **Inputs**:
#
# * `draft` (str): The essay text to reflect on.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-5.1"`.
#
# **Output**:
#
# * A string with feedback in paragraph form.

# %%
def reflect_on_draft(draft: str, model: str = "openai:gpt-5.1") -> str:
    instruction = f"""
    Reflect critically on the following draft essay.
    Identify areas for improvement in structure, clarity, argument strength, or style.
    Provide constructive feedback in paragraph form.

    Draft:
    {draft}
    """
    response = client.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": instruction}],
        temperature=1.0,
    )
    return response.choices[0].message.content

# %% [markdown]
# ### 🔁 `revise_draft` Function
#
# **Objective**:
# Implement a function called `revise_draft` that improves a given essay draft based on feedback from a reflection step.
#
# **Inputs**:
#
# * `original_draft` (str): The initial version of the essay.
# * `reflection` (str): Constructive feedback or critique on the draft.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-5.1"`.
#
# **Output**:
#
# * A string containing the revised and improved essay.

# %%
def revise_draft(original_draft: str, reflection: str, model: str = "openai:gpt-5.1") -> str:
    instruction = f"""
    Revise the following essay draft using the feedback provided.
    Make improvements in clarity, coherence, argumentation, and flow.
    Return only the improved essay.

    Original Draft:
    {original_draft}

    Feedback:
    {reflection}
    """
    response = client.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": instruction}],
        temperature=1.0,
    )
    return response.choices[0].message.content

# %% [markdown]
# ### 🧪 Test the Reflective Writing Workflow
#
# Use the functions you implemented to simulate the complete writing workflow:
#
# 1. **Generate a draft** in response to the essay prompt.
# 2. **Reflect** on the draft to identify improvements.
# 3. **Revise** the draft using the feedback.

# %%
essay_prompt = "چگونه یک پروژه Fastapi ساختار یافته و ماژولار مناسب production داشته باشیم؟"

# Agente 1 – Draft
draft = generate_draft(essay_prompt)
print("📝 Draft:\n")
print(draft)

# Agente 2 – Reflection
feedback = reflect_on_draft(draft)
print("\n🧠 Feedback:\n")
print(feedback)

# Agente 3 – Revision
revised = revise_draft(draft, feedback)
print("\n✍️ Revised:\n")
print(revised)
# Out:
# 📝 Draft:
#
# در این نوشته به پرسش «چگونه یک پروژه FastAPI ساختار یافته و ماژولار مناسب محیط production داشته باشیم؟» پاسخ می‌دهیم. هدف، ارائه‌ی یک دید کلی و عملی برای طراحی، سازمان‌دهی و آماده‌سازی پروژه‌ای است که نه‌تنها در محیط توسعه (development) کار کند، بلکه در مقیاس بزرگ‌تر و با الزامات جدی‌تر production نیز قابل اتکا، قابل نگه‌داری و قابل توسعه باشد. برای این منظور، ابتدا به اهمیت ساختار و ماژولار بودن پروژه می‌پردازیم، سپس الگوی‌های رایج ساختاردهی، مدیریت تنظیمات، جداسازی لایه‌ها، تست‌پذیری، امنیت و استقرار را مرور می‌کنیم و در پایان نکاتی جمع‌بندی می‌گردد که به‌عنوان چک‌لیست عملی قابل استفاده است.
#
# ---
#
# ## مقدمه
#
# FastAPI به‌دلیل سادگی، کارایی بالا و پشتیبانی خوب از تایپ‌ها و async، انتخاب محبوبی برای ساخت APIهای مدرن است. با این حال، بسیاری از نمونه‌کدها و آموزش‌ها، روی پروژه‌های کوچک و ساده تمرکز دارند؛ پروژه‌هایی که یک فایل main.py دارند و چند endpoint ساده. در محیط production، چنین رویکردی خیلی زود تبدیل به کدی پیچیده، سخت‌فهم و شکننده می‌شود.
#
# برای داشتن یک پروژه‌ی FastAPI مناسب production، لازم است از ابتدا به چند اصل کلیدی توجه شود:
#
# - **ساختار دایرکتوری‌ها و ماژول‌ها** روشن و قابل فهم باشد.
# - **جداسازی لایه‌ها** (presentation، business، data) رعایت شود.
# - **مدیریت تنظیمات و کانفیگ** امن، قابل نسخه‌گذاری و قابل تغییر باشد.
# - **قابلیت تست، لاگ‌گیری و مانیتورینگ** از ابتدا در نظر گرفته شود.
# - **مسائل امنیتی و استقرار** در طراحی اولیه‌ی پروژه لحاظ شوند.
#
# در ادامه، این اصول را به‌صورت منظم بررسی می‌کنیم.
#
# ---
#
# ## بدنه
#
# ### ۱. اهمیت ساختار و ماژولار بودن در پروژه‌های FastAPI
#
# در پروژه‌های کوچک، عموماً همه‌چیز در چند فایل محدود جمع می‌شود: modelها، routeها، dependencyها و تنظیمات. این حالت برای یادگیری مناسب است، اما در production:
#
# - تیم‌های مختلف باید روی بخش‌های مختلف کار کنند.
# - نیاز به تست واحد، تست یکپارچه و CI/CD داریم.
# - تغییرات مداوم در کسب‌وکار و نیازمندی‌ها رخ می‌دهد.
#
# اگر پروژه ساختار نداشته باشد، هر تغییر کوچک زمان‌بر می‌شود و احتمال بروز خطا بالا می‌رود. ساختار ماژولار کمک می‌کند:
#
# - هر ماژول وظیفه‌ی مشخصی داشته باشد (اصل Single Responsibility).
# - کد قابل‌استفاده‌ی مجدد باشد.
# - وابستگی‌ها کنترل شوند و از coupling شدید جلوگیری شود.
#
# بنابراین، طراحی ساختار پروژه از همان ابتدا یک سرمایه‌گذاری بلندمدت است.
#
# ---
#
# ### ۲. نمونه‌ای از ساختار پوشه‌ها در یک پروژه‌ی production
#
# الگوی واحد و استانداردی وجود ندارد، اما بعضی ساختارها رایج و اثبات‌شده هستند. یک نمونه‌ی ساده، اما قابل توسعه، می‌تواند چنین باشد:
#
# ```bash
# app/
#     core/
#         config.py
#         security.py
#         logging.py
#     api/
#         v1/
#             endpoints/
#                 users.py
#                 items.py
#             dependencies/
#                 auth.py
#                 db.py
#     models/
#         user.py
#         item.py
#     schemas/
#         user.py
#         item.py
#     services/
#         user_service.py
#         item_service.py
#     db/
#         base.py
#         session.py
#         migrations/   # مثلا برای Alembic
#     tests/
#         api/
#         services/
#         ...
#     main.py
# ```
#
# در این ساختار:
#
# - **core/** شامل تنظیمات و اجزای عمومی سیستم است.
# - **api/** شامل لایه‌ی ارائه (routes، dependencies) است.
# - **models/** برای مدل‌های دیتابیس (ORM، مثلاً SQLAlchemy).
# - **schemas/** برای Pydantic مدل‌ها (ورودی/خروجی API).
# - **services/** شامل منطق تجاری است؛ لایه‌ای بین api و db.
# - **db/** برای مدیریت اتصال، session، migrationها.
# - **tests/** برای تست‌ها.
#
# این ساختار به تفکیک نقش‌ها کمک می‌کند. برای مثال، تغییر در مدل دیتابیس الزاماً به تغییر در endpointها منجر نمی‌شود؛ چون schema و service به‌عنوان لایه‌های میانی عمل می‌کنند.
#
# ---
#
# ### ۳. مدیریت تنظیمات (Configuration Management)
#
# در محیط production، تنظیمات و کانفیگ‌ها بسیار مهم هستند: آدرس دیتابیس، کلیدهای API، سطوح لاگ، تنظیمات امنیتی و… نباید به‌صورت هاردکد در کد قرار گیرند.
#
# بهترین الگوها:
#
# 1. **استفاده از متغیرهای محیطی (Environment Variables):**
#    - در Docker، Kubernetes یا هر سیستم استقرار دیگری، متغیرهای محیطی روش اصلی تنظیمات هستند.
#    - مثلاً: `DATABASE_URL`, `SECRET_KEY`, `ENV=production`.
#
# 2. **استفاده از Pydantic Settings:**
#    - FastAPI به‌خوبی با Pydantic سازگار است و می‌توان یک کلاس تنظیمات ساخت:
#      ```python
#      from pydantic import BaseSettings
#
#      class Settings(BaseSettings):
#          database_url: str
#          secret_key: str
#          debug: bool = False
#
#          class Config:
#              env_file = ".env"
#      ```
#
# 3. **تفکیک تنظیمات برای محیط‌های مختلف:**
#    - development، staging، production می‌توانند فایل‌های env متفاوت داشته باشند.
#    - لازم است در CI/CD مشخص شود کدام تنظیمات کجا استفاده می‌شود.
#
# 4. **امنیت تنظیمات:**
#    - فایل‌های `.env` حاوی secrets نباید در مخزن عمومی قرار گیرند.
#    - استفاده از vaultها (مثل HashiCorp Vault یا secret managerهای cloud) در پروژه‌های جدی توصیه می‌شود.
#
# ---
#
# ### ۴. جداسازی لایه‌ها: API، منطق کسب‌وکار، داده
#
# برای ساختار ماژولار، جداسازی لایه‌ها کلیدی است:
#
# 1. **لایه‌ی API (Presentation Layer):**
#    - شامل endpointها، مسیرها، dependencyها برای احراز هویت، pagination، و غیره.
#    - فقط مسئول دریافت درخواست، اعتبارسنجی اولیه و انتقال داده به لایه‌ی منطق است.
#
# 2. **لایه‌ی منطق کسب‌وکار (Service Layer):**
#    - تابع‌ها یا کلاس‌هایی که عملیات اصلی کسب‌وکار را انجام می‌دهند، مثل:
#      - ثبت کاربر جدید
#      - اعمال قوانین تخفیف
#      - مدیریت سفارش‌ها
#    - این لایه باید تا حد ممکن از جزئیات API و دیتابیس مستقل باشد.
#
# 3. **لایه‌ی داده (Data Access Layer):**
#    - با دیتابیس یا سایر سیستم‌های ذخیره‌سازی ارتباط دارد.
#    - شامل مدل‌های ORM، repositoryها و کار با session.
#
# این جداسازی باعث می‌شود:
#
# - بتوان منطق را بدون تغییر در API تست کرد.
# - تغییر دیتابیس یا روش ذخیره‌سازی تأثیر کمتری روی سایر بخش‌ها داشته باشد.
# - از تداخل concerns جلوگیری شود.
#
# ---
#
# ### ۵. dependency injection و مدیریت وابستگی‌ها
#
# FastAPI به‌صورت داخلی از dependency injection پشتیبانی می‌کند. استفاده‌ی درست از این قابلیت در پروژه‌ی production بسیار مفید است:
#
# - می‌توان اتصال دیتابیس، سرویس‌های خارجی، و حتی سرویس‌های داخلی را به‌عنوان dependency تعریف کرد.
# - در تست‌ها، این dependencyها را mock یا override کرد.
#
# برای مثال، مدیریت session دیتابیس:
#
# ```python
# from fastapi import Depends
# from sqlalchemy.orm import Session
# from app.db.session import get_db
#
# @router.get("/users")
# def list_users(db: Session = Depends(get_db)):
#     return user_service.list_users(db)
# ```
#
# این رویکرد:
#
# - کد را تست‌پذیر می‌کند.
# - وابستگی‌ها را صریح و قابل مدیریت می‌سازد.
#
# ---
#
# ### ۶. تست‌پذیری، لاگ‌گیری و مانیتورینگ
#
# پروژه‌ی production بدون تست و لاگ شبیه سیستمی است که در تاریکی کار می‌کند.
#
# 1. **تست‌ها:**
#    - تست واحد (unit tests) برای services و منطق اصلی.
#    - تست یکپارچه (integration tests) برای endpointها با دیتابیس تست.
#    - استفاده از pytest و ابزارهای کمکی مانند `TestClient` در FastAPI.
#
# 2. **لاگ‌گیری:**
#    - تنظیم logging در ماژول core/logging.py.
#    - تعریف format مناسب، سطح لاگ‌ها (INFO, ERROR, DEBUG).
#    - ارسال لاگ‌ها به سیستم‌های جمع‌آوری لاگ (ELK, Loki, Cloud Logging).
#
# 3. **مانیتورینگ و متریک‌ها:**
#    - استفاده از Prometheus، Grafana یا سرویس‌های مشابه برای جمع‌آوری متریک‌ها (تعداد درخواست‌ها، latency، خطاها).
#    - اضافه کردن health-check endpoint برای بررسی وضعیت سرویس.
#
# ---
#
# ### ۷. امنیت، احراز هویت و مجوزها
#
# در production، امنیت باید از ابتدا جزئی از طراحی باشد:
#
# 1. **احراز هویت (Authentication):**
#    - استفاده از OAuth2 با JWT، یا ارتباط با identity providerها.
#    - FastAPI مستندات خوبی در این زمینه دارد که باید در ماژول `core/security.py` یا `api/dependencies/auth.py` پیاده‌سازی شوند.
#
# 2. **مجوزها (Authorization):**
#    - تعریف نقش‌ها (Role) و سطح دسترسی‌ها.
#    - استفاده از dependencyها برای بررسی مجوز در endpointها.
#
# 3. **محافظت در برابر حملات رایج:**
#    - محدود کردن اندازه‌ی درخواست‌ها.
#    - محافظت در برابر brute-force روی login.
#    - استفاده از HTTPS در استقرار، تنظیم HSTS و headerهای امنیتی.
#
# ---
#
# ### ۸. استقرار (Deployment) و تنظیمات production
#
# یک پروژه‌ی ساختار یافته، باید به‌راحتی قابل استقرار باشد:
#
# 1. **استفاده از Uvicorn/Gunicorn:**
#    - برای محیط production، توصیه می‌شود از ترکیب Gunicorn + Uvicorn worker استفاده شود.
#    - مثال:
#      ```bash
#      gunicorn -k uvicorn.workers.UvicornWorker app.main:app
#      ```
#
# 2. **Containerization با Docker:**
#    - ساخت Dockerfile به‌گونه‌ای که:
#      - وابستگی‌ها در مرحله‌ی build نصب شوند.
#      - از imageهای slim و امن استفاده شود.
#    - استفاده از docker-compose برای مدیریت سرویس‌ها (دیتابیس، کش، API).
#
# 3. **Reverse proxy (مثل Nginx):**
#    - برای مدیریت requestها، TLS termination، و load balancing.
#
# 4. **مقیاس‌پذیری:**
#    - آماده‌سازی پروژه برای اجرا در چند replica.
#    - مدیریت state (مثلاً استفاده از Redis برای sessionهای اشتراکی یا queue).
#
# ---
#
# ### ۹. مستندسازی و قراردادها
#
# FastAPI خودکار مستندات OpenAPI تولید می‌کند، اما در پروژه‌ی production، بهتر است:
#
# - تعریف schemaها دقیق و شامل توضیحات مناسب باشد.
# - نسخه‌بندی APIها انجام شود (مثلاً `/api/v1`, `/api/v2`).
# - قراردادها (API contract) با تیم‌های فرانت‌اند و سایر مصرف‌کنندگان API به‌صورت رسمی و نسخه‌دار مدیریت شود.
#
# این کار مانع از بروز ناسازگاری‌ها و شکستن backward compatibility می‌شود.
#
# ---
#
# ## نتیجه‌گیری
#
# برای داشتن یک پروژه‌ی FastAPI ساختار یافته و ماژولار مناسب production، تنها کافی نیست که چند endpoint سریع و کارآمد بنویسیم. آنچه در محیط production اهمیت دارد، قابلیت نگه‌داری، توسعه و اعتماد به سیستم در طول زمان است. با طراحی یک ساختار پوشه‌ی منطقی، جداسازی لایه‌ها (API، منطق کسب‌وکار، لایه‌ی داده)، مدیریت حرفه‌ای تنظیمات، استفاده از dependency injection، توجه به تست‌پذیری، لاگ‌گیری و مانیتورینگ، و لحاظ کردن مسائل امنیتی و استقرار از ابتدا، می‌توان پروژه‌ای ساخت که با رشد نیازمندی‌ها و افزایش بار، همچنان پایدار و قابل اتکا باقی بماند.
#
# در عمل، هیچ ساختار واحد و مطلقی وجود ندارد و هر تیم با توجه به نیازها، ابزارها و تجربه‌ی خود، الگوی مناسب را پیدا می‌کند. اما اصولی که در این نوشته مرور شد می‌توانند به‌عنوان چارچوبی برای ارزیابی و طراحی پروژه‌ی FastAPI در سطح production به کار گرفته شوند. با پایبندی به این اصول، احتمال تبدیل شدن پروژه به «کد اسپاگتی» کم می‌شود و تیم توسعه می‌تواند با اعتماد بیشتری به توسعه‌ی بلندمدت فکر کند.
#
# 🧠 Feedback:
#
# این متن از نظر محتوا غنی، منظم و نسبتاً کامل است؛ اما برای تبدیل شدن به یک مقاله قوی‌تر و خواندنی‌تر در چند سطح می‌توان آن را بهبود داد:
#
# از نظر ساختار کلی، مقاله به‌خوبی از مقدمه–بدنه–نتیجه‌گیری پیروی می‌کند و سرفصل‌ها منطقی چیده شده‌اند. با این حال، بدنه کمی «فهرست‌محور» است؛ هر بخش بیشتر شبیه راهنمای نکته‌ای است تا یک بحث تحلیلی. می‌توان در ابتدای هر بخش یک یا دو جمله‌ی گذار اضافه کرد که نشان دهد چرا این بخش در پاسخ به پرسش اصلی ضروری است و چگونه به بخش قبل و بعد مرتبط می‌شود. مثلاً در بخش «مدیریت تنظیمات» قبل از ورود به لیست، یک مثال کوتاه از یک کانفیگ بد در فضای production و پیامدهایش، هم زمینه می‌سازد و هم خواننده را درگیر می‌کند. همچنین، شاید بهتر باشد بخش‌ها کمی ادغام یا اولویت‌بندی شوند؛ مثلاً «dependency injection» را می‌توان زیرمجموعه‌ی «جداسازی لایه‌ها و تست‌پذیری» آورد تا ساختار مقاله کمتر پراکنده و بیشتر موضوع‌محور باشد.
#
# از نظر وضوح، زبان متن عمدتاً روان و استاندارد است، اما در برخی جاها جملات طولانی و چندلایه هستند که خواننده‌ی متوسط را خسته می‌کنند. کوتاه‌تر کردن بعضی جملات و پرهیز از تکرارهای معنایی (مثل «قابل اتکا، قابل نگه‌داری و قابل توسعه» که می‌توان برای تنوع در جاهای مختلف به‌صورت متفاوت بیان‌شان کرد) به خوانایی کمک می‌کند. ترکیب انگلیسی–فارسی در واژگان فنی (production، development، service layer، config) طبیعتاً اجتناب‌ناپذیر است، اما بهتر است یک‌رسانه باشد: یا معادل فارسی ثابت و یک‌دست (مثلاً «محیط عملیاتی» برای production) یا اگر ترجیح می‌دهید انگلیسی را حفظ کنید، در اولین اشاره، معادل فارسی را بیاورید و بعداً فقط یکی را استفاده کنید. همچنین، در بخش‌هایی مثل ساختار پوشه‌ها، توضیح مختصر روی برخی پوشه‌ها (مثلاً تفاوت دقیق models و schemas) می‌تواند از ابهام برای خواننده‌ی کمتر آشنا جلوگیری کند.
#
# از نظر قوت استدلال، مقاله بیشتر «راهنمای خوب‌عمل‌کردن» است تا یک متن کاملاً «استدلالی». یعنی پیشنهادها درست‌اند، اما کمتر نشان می‌دهد که «اگر این کار را نکنید چه می‌شود» یا «چرا این رویکرد از رویکردهای دیگر بهتر است». برای تقویت بعد انتقادی و استدلالی، می‌توانید از چند ضدنمونه استفاده کنید: مثلاً توضیح دهید پروژه‌ای که همه‌چیز را در یک فایل نگه می‌دارد هنگام افزودن ویژگی‌های جدید چه مشکلات مشخصی در تست و نگه‌داری پیدا می‌کند؛ یا اینکه عدم تفکیک لایه‌ها چگونه باعث coupling شدید و سخت شدن جایگزینی دیتابیس می‌شود. بیان این «سناریوهای شکست» حتی به شکل کوتاه، به خواننده نشان می‌دهد که توصیه‌ها صرفاً «بهتر» نیستند، بلکه جلوی مشکلات واقعی را می‌گیرند. همچنین، تا حدی می‌توانید به بحث‌های عمومی‌تر معماری اشاره کنید (مثل مقایسه مختصر با معماری‌های monolith تمیز یا microservices) تا جایگاه این ساختار پیشنهاد شده در منظومه‌ی بزرگ‌تر معماری نرم‌افزار روشن‌تر شود.
#
# از نظر سبک و لحن، متن حرفه‌ای، آموزشی و به‌نسبت بی‌طرف است، اما می‌تواند کمی جذاب‌تر شود. در حال حاضر، تقریباً همه‌جا از لحن توضیحی–دستوری («بهترین الگوها:»، «لازم است…») استفاده کرده‌اید. اگر گه‌گاهی لحن را از «باید» به «می‌توانید» و از «دستور» به «تجربه» تغییر دهید (مثلاً اضافه کردن جملاتی از جنس «در تجربه‌ی بسیاری از تیم‌ها…» یا «در عمل دیده می‌شود که…»)، صدا و شخصیت نویسنده بیشتر به چشم می‌آید. همچنین، می‌توانید در پایان بعضی بخش‌ها یک «جمع‌بندی کوچک» یک‌جمله‌ای بگذارید که پیام کلیدی را برجسته کند؛ این کار مخصوصاً در بخش‌های طولانی مثل تست و لاگ‌گیری مفید است.
#
# در سطح جزئی‌تر، چند نکته‌ی سبک‌شناسانه وجود دارد: ابتدا و انتهای متن به‌خوبی به سؤال اصلی ارجاع می‌دهند، اما در بخش‌های میانی کمتر به خود «پرسش» بازمی‌گردید. می‌توانید وسط مقاله یک بار دیگر صراحتاً یادآوری کنید که تمام این بحث‌ها در پاسخ به پرسش «چگونه…» است و مثلاً بگویید «تا اینجا دیدیم که ساختار پوشه‌ها و جداسازی لایه‌ها چگونه به تولید یک پروژه‌ی مناسب production کمک می‌کنند؛ حالا به تنظیمات و امنیت می‌پردازیم که دو ستون دیگر این هدف هستند». این نوع ارجاع دوره‌ای انسجام کلی متن را تقویت می‌کند. همچنین، نتیجه‌گیری اگرچه شسته‌رفته است، می‌تواند کمی عملی‌تر شود؛ مثلاً به‌جای یک جمع‌بندی صرفاً مفهومی، یک «گام‌های پیشنهادی» خیلی کوتاه (۳–۴ قدم) برای تیمی که می‌خواهد از صفر شروع کند ارائه کنید تا خواننده احساس کند پس از خواندن متن، می‌داند از کجا شروع کند.
#
# در مجموع، مقاله از نظر محتوا و نظم بسیار خوب است و عمده‌ی نکات مهم برای یک پروژه‌ی FastAPI در محیط production را پوشش می‌دهد. تقویت پیوند بین بخش‌ها، افزودن کمی استدلال و مثال منفی، ساده‌سازی برخی جملات و دادن یک مسیر عملی در نتیجه‌گیری، می‌تواند آن را از یک «چک‌لیست توصیفی» به یک متن راهبردی و اثرگذارتر تبدیل کند.
#
# ✍️ Revised:
#
# در این نوشته به پرسش «چگونه یک پروژه‌ی FastAPI ساختار یافته و ماژولار مناسب محیط production داشته باشیم؟» پاسخ می‌دهیم. هدف، ارائه‌ی یک دید کلی و عملی برای طراحی، سازمان‌دهی و آماده‌سازی پروژه‌ای است که نه‌تنها در محیط توسعه (development) قابل استفاده باشد، بلکه در مقیاس بزرگ‌تر و با الزامات جدی‌تر محیط عملیاتی (production) نیز پایدار، قابل نگه‌داری و قابل توسعه باقی بماند.
#
# برای رسیدن به این هدف، لازم است از ابتدا به چند اصل کلیدی توجه شود: ساختار روشن دایرکتوری‌ها و ماژول‌ها، جداسازی لایه‌ها، مدیریت حرفه‌ای تنظیمات، قابلیت تست و مشاهده‌پذیری (لاگ‌گیری و مانیتورینگ)، و در نهایت امنیت و نحوه‌ی استقرار. در ادامه، با نگاهی یکپارچه به این اصول، نشان می‌دهیم که چگونه می‌توان یک پروژه‌ی FastAPI را از حالت «نمونه‌کد آموزشی» به یک سرویس عملیاتی قابل اتکا ارتقا داد.
#
# ---
#
# ## مقدمه
#
# FastAPI به‌دلیل سادگی، کارایی بالا و پشتیبانی خوب از تایپ‌ها و async، انتخاب محبوبی برای ساخت APIهای مدرن است. بسیاری از نمونه‌کدها و آموزش‌ها، حول پروژه‌های کوچک شکل گرفته‌اند: یک فایل main.py، چند endpoint ساده و شاید یک مدل دیتابیس. این مثال‌ها برای شروع و یادگیری عالی‌اند، اما اگر همان الگو را بدون تغییر وارد production کنیم، خیلی زود با سیستمی مواجه می‌شویم که هر تغییر کوچک در آن پرهزینه و پرریسک است.
#
# در محیط production:
#
# - تیم‌های مختلف روی بخش‌های مختلف سیستم کار می‌کنند.
# - تغییرات کسب‌وکار مداوم است و باید سریع و ایمن اعمال شود.
# - نیاز به تست، لاگ‌گیری، مانیتورینگ و استقرار خودکار جدی است.
#
# اگر پروژه بدون ساختار و ماژول‌بندی مناسب رشد کند، به‌سمت «کد اسپاگتی» می‌رود؛ جایی که افزودن یک ویژگی ساده، ممکن است چندین نقطه‌ی ظریف و شکننده را تحت تأثیر قرار دهد. برای جلوگیری از این سناریوی شکست، در ادامه به‌صورت گام‌به‌گام بررسی می‌کنیم که یک پروژه‌ی FastAPI مناسب محیط production چه ویژگی‌هایی دارد و چگونه می‌توان از ابتدا این ویژگی‌ها را در طراحی لحاظ کرد.
#
# ---
#
# ## ۱. چرا ساختار و ماژولار بودن در FastAPI حیاتی است؟
#
# نقطه‌ی شروع پاسخ به پرسش اصلی، مسئله‌ی ساختار است. اگر ساختار پروژه از ابتدا روشن و ماژولار نباشد، سایر تلاش‌ها (تست، امنیت، استقرار) روی پایه‌ای لرزان بنا می‌شوند.
#
# در پروژه‌های کوچک، معمولاً همه‌چیز در چند فایل محدود قرار می‌گیرد: مدل‌ها، routeها، dependencyها و تنظیمات. این روش برای یادگیری مناسب است، اما در پروژه‌های جدی، پیامدهای آن کاملاً مشهود است. برای مثال، اگر همه‌ی کدها در main.py باشند:
#
# - اضافه کردن یک endpoint جدید، نیازمند جست‌وجوی طولانی در فایل و درک روابط متداخل است.
# - تست کردن منطق کسب‌وکار بدون بالا آوردن کل اپلیکیشن تقریباً ناممکن می‌شود.
# - هر تغییر در دیتابیس، مستقیماً روی endpointها اثر می‌گذارد و ریسک شکست backward compatibility را بالا می‌برد.
#
# در مقابل، ساختار ماژولار کمک می‌کند:
#
# - هر بخش وظیفه‌ی مشخصی داشته باشد (اصل Single Responsibility).
# - کد قابل استفاده‌ی مجدد شود و تکرارهای بیهوده کاهش یابد.
# - وابستگی‌ها کنترل شوند و از coupling شدید بین لایه‌ها جلوگیری شود.
#
# به‌عبارت دیگر، طراحی ساختار پروژه در ابتدای کار یک هزینه‌ی کوچک است که در میان‌مدت و بلندمدت، بهره‌ی بزرگی در نگه‌داری و توسعه بازمی‌گرداند.
#
# ---
#
# ## ۲. نمونه‌ای از ساختار پوشه‌ها در یک پروژه‌ی production
#
# پس از روشن شدن اهمیت ساختار، طبیعی است به این پرسش برسیم که «این ساختار در عمل چه شکلی دارد؟». الگوی واحد و مطلقی وجود ندارد، اما الگوهای رایج و آزموده‌شده می‌توانند نقطه‌ی شروع خوبی باشند. یک نمونه‌ی ساده اما قابل توسعه، می‌تواند چنین باشد:
#
# ```bash
# app/
#     core/
#         config.py
#         security.py
#         logging.py
#     api/
#         v1/
#             endpoints/
#                 users.py
#                 items.py
#             dependencies/
#                 auth.py
#                 db.py
#     models/
#         user.py
#         item.py
#     schemas/
#         user.py
#         item.py
#     services/
#         user_service.py
#         item_service.py
#     db/
#         base.py
#         session.py
#         migrations/   # مثلا برای Alembic
#     tests/
#         api/
#         services/
#         ...
#     main.py
# ```
#
# در این ساختار:
#
# - **core/**
#   شامل تنظیمات و اجزای عمومی سیستم است: مدیریت کانفیگ، امنیت پایه، و راه‌اندازی logging. این پوشه جای «زیرساخت» اپلیکیشن است.
#
# - **api/**
#   لایه‌ی ارائه (Presentation Layer) را در بر می‌گیرد: routeها، endpointها و dependencyهای مربوط به احراز هویت، اتصال به دیتابیس و سایر وابستگی‌های سطح HTTP. برای مثال، `api/v1/endpoints/users.py` فقط مسئول تعریف مسیرها و فراخوانی سرویس‌های مربوطه است.
#
# - **models/**
#   مدل‌های دیتابیس (مثلاً SQLAlchemy) در این پوشه قرار می‌گیرند؛ چیزی که واقعاً روی جدول‌ها و روابط در دیتابیس نگاشت می‌شود.
#
# - **schemas/**
#   مدل‌های Pydantic برای ورودی/خروجی API در اینجا تعریف می‌شوند. تفاوت مهم با models این است که schemas نمای بیرونی داده را برای API مشخص می‌کنند (مثلاً چه فیلدهایی به کلاینت نشان داده شوند)، در حالی که models ساختار داده را در سطح ذخیره‌سازی تعیین می‌کنند. این تفکیک اجازه می‌دهد تغییرات دیتابیس لزوماً به تغییر قرارداد API منجر نشود.
#
# - **services/**
#   لایه‌ی منطق کسب‌وکار (Service Layer). عملیات اصلی مانند ثبت کاربر جدید، اعمال قوانین تخفیف یا مدیریت سفارش‌ها در اینجا پیاده‌سازی می‌شود. این لایه بین api و db قرار می‌گیرد و تا حد امکان از جزئیات HTTP و ذخیره‌سازی مستقل است.
#
# - **db/**
#   برای مدیریت اتصال به دیتابیس، session، و migrationها. مثلاً `session.py` تابعی برای تولید Session و `migrations/` اسکریپت‌های Alembic را در خود دارد.
#
# - **tests/**
#   ساختار تست‌ها را منعکس می‌کند: تست endpointها، تست سرویس‌ها و… هرچه ساختار اپلیکیشن تمیزتر باشد، ساختن تست‌های هم‌ساختار آسان‌تر می‌شود.
#
# این ساختار به تفکیک نقش‌ها کمک می‌کند. برای مثال، اگر نیاز باشد فیلد جدیدی به جدول user اضافه شود، ابتدا مدل دیتابیس در `models/user.py` به‌روزرسانی می‌شود، سپس schema مربوط در `schemas/user.py` و در نهایت سرویس‌ها در `services/user_service.py`. endpointها فقط در صورتی تغییر می‌کنند که قرارداد API تغییر کند. نتیجه این است که وابستگی‌ها شفاف و قابل کنترل می‌مانند.
#
# تا اینجا دیدیم که صرفاً با تعریف یک ساختار پوشه‌ی منطقی و جداسازی لایه‌ها، قدم بزرگی به‌سمت پاسخ به پرسش «چگونه یک پروژه‌ی FastAPI مناسب production داشته باشیم؟» برداشته‌ایم. در ادامه، به ستون‌های دیگری می‌پردازیم که این ساختار را عملی و ایمن می‌کنند.
#
# ---
#
# ## ۳. مدیریت تنظیمات (Configuration Management)
#
# ساختار خوب بدون مدیریت حرفه‌ای تنظیمات، در production به‌سرعت با مشکلات عملی روبه‌رو می‌شود. یک مثال رایج، هاردکد کردن آدرس دیتابیس یا کلیدهای امنیتی در کد است. در چنین حالتی، تغییر محیط از development به staging یا production نیازمند تغییر مستقیم در کد است؛ کاری که هم پرریسک است و هم در فرایند CI/CD خوب جا نمی‌گیرد.
#
# برای پرهیز از این وضعیت و فراهم کردن انعطاف لازم، چند الگو متداول و مؤثر وجود دارد:
#
# 1. **استفاده از متغیرهای محیطی (Environment Variables)**
#    در اغلب سیستم‌های استقرار (Docker، Kubernetes، سرویس‌های ابری)، تنظیمات از طریق متغیرهای محیطی مدیریت می‌شوند. مثلاً:
#
#    - `DATABASE_URL`
#    - `SECRET_KEY`
#    - `ENV=production`
#
#    این رویکرد اجازه می‌دهد که همان کد در محیط‌های مختلف با تنظیمات متفاوت اجرا شود، بدون آن‌که نیازی به تغییر در مخزن کد باشد.
#
# 2. **استفاده از Pydantic Settings**
#    FastAPI با Pydantic سازگار است و می‌توان کلاس تنظیمات ساخت که متغیرهای محیطی را به‌شکل ساخت‌یافته بخواند:
#
#    ```python
#    from pydantic import BaseSettings
#
#    class Settings(BaseSettings):
#        database_url: str
#        secret_key: str
#        debug: bool = False
#
#        class Config:
#            env_file = ".env"
#    ```
#
#    با این کار، تنظیمات در سطح کد به‌صورت یک شیء واحد در دسترس هستند و می‌توان آن را به‌عنوان dependency در بخش‌های مختلف تزریق کرد.
#
# 3. **تفکیک تنظیمات برای محیط‌های مختلف**
#    محیط‌های development، staging و production می‌توانند فایل‌های `.env` یا مجموعه‌ی متغیرهای محیطی متفاوت داشته باشند. در فرایند CI/CD باید مشخص باشد که هر محیط از کدام تنظیمات استفاده می‌کند تا خطای انسانی در جابه‌جایی کانفیگ‌ها کاهش یابد.
#
# 4. **امنیت تنظیمات**
#    فایل‌های `.env` حاوی secrets نباید در مخزن عمومی قرار گیرند. در پروژه‌های جدی، استفاده از ابزارهایی مانند HashiCorp Vault یا secret managerهای سرویس‌های ابری رایج است. به این ترتیب، دسترسی به secrets قابل کنترل و audit خواهد بود.
#
# جمع‌بندی این بخش آن است که مدیریت تنظیمات، اگرچه در ظاهر جزئی به‌نظر می‌رسد، در عمل یکی از نقاط شکست رایج در پروژه‌های بدون ساختار است. طراحی درست کانفیگ‌ها، هم امنیت را افزایش می‌دهد و هم چرخه‌ی استقرار را ساده و قابل اعتماد می‌کند.
#
# ---
#
# ## ۴. جداسازی لایه‌ها: API، منطق کسب‌وکار و داده
#
# ساختار پوشه‌ها، بازتابی از یک اصل معماری عمیق‌تر است: جداسازی لایه‌ها. این جداسازی در پاسخ به پرسش اصلی نقش بنیادی دارد، زیرا مستقیم روی تست‌پذیری، انعطاف و امکان جایگزینی اجزا اثر می‌گذارد.
#
# ### ۴.۱. لایه‌ی API (Presentation Layer)
#
# این لایه شامل endpointها، مسیرها و dependencyهای سطح HTTP است. مسئولیت اصلی آن:
#
# - دریافت درخواست،
# - اعتبارسنجی اولیه (بر اساس schemas)،
# - و انتقال داده‌ی معتبر به لایه‌ی منطق کسب‌وکار.
#
# اگر منطق کسب‌وکار را در همین لایه پیاده‌سازی کنیم (مثلاً کل عملیات ثبت کاربر را در خود endpoint بنویسیم)، خیلی زود endpointها به بلوک‌های سنگین و سخت‌تست تبدیل می‌شوند؛ بلوک‌هایی که برای هر تغییر کوچک در منطق باید روی آن‌ها کار کنیم.
#
# ### ۴.۲. لایه‌ی منطق کسب‌وکار (Service Layer)
#
# در services، عملیات اصلی سیستم پیاده‌سازی می‌شود؛ بدون وابستگی مستقیم به HTTP. برای مثال:
#
# - ثبت کاربر جدید،
# - محاسبه‌ی مبلغ نهایی سفارش با تخفیف،
# - مدیریت چرخه‌ی حیات یک درخواست.
#
# این لایه باید تا حد ممکن از جزئیات API و دیتابیس مستقل باشد. وقتی این استقلال رعایت شود، می‌توان منطق کسب‌وکار را به‌صورت مستقل تست کرد، یا حتی در آینده آن را در قالب سرویس دیگری (مثلاً یک worker background) استفاده کرد، بدون آن‌که به قرارداد API دست بزنیم.
#
# ### ۴.۳. لایه‌ی داده (Data Access Layer)
#
# این لایه با دیتابیس یا سایر سیستم‌های ذخیره‌سازی ارتباط دارد. شامل مدل‌های ORM، repositoryها و کار با session است. اگر این لایه را با لایه‌ی منطق کسب‌وکار قاطی کنیم، تغییر دیتابیس (مثلاً از PostgreSQL به یک دیتابیس دیگر یا از ORM به queryهای خام) به‌معنای بازنویسی بخش بزرگی از منطق سیستم خواهد بود؛ نمونه‌ی واضحی از coupling شدید.
#
# در معماری‌های monolith تمیز، همین الگوی لایه‌ای باعث می‌شود که monolith قابل مدیریت و توسعه باقی بماند. در معماری‌های microservices نیز هر سرویس داخلی غالباً از همین تفکیک لایه‌ها بهره می‌برد. بنابراین، جداسازی لایه‌ها نه‌تنها برای FastAPI، بلکه در منظومه‌ی بزرگ‌تر معماری نرم‌افزار یک اصل پذیرفته‌شده است.
#
# ---
#
# ## ۵. مدیریت وابستگی‌ها و dependency injection
#
# برای آن‌که جداسازی لایه‌ها در عمل مؤثر باشد، باید وابستگی‌ها بین این لایه‌ها کنترل‌شده و قابل تزریق باشند. FastAPI به‌صورت داخلی از dependency injection پشتیبانی می‌کند و این قابلیت یکی از عوامل مهم مناسب بودن آن برای محیط production است.
#
# با dependency injection می‌توان اتصال به دیتابیس، سرویس‌های خارجی، و حتی سرویس‌های داخلی را به‌صورت dependency تعریف کرد و در جاهای مختلف استفاده یا در تست‌ها جایگزین (override) کرد.
#
# مثلاً مدیریت session دیتابیس:
#
# ```python
# from fastapi import Depends
# from sqlalchemy.orm import Session
# from app.db.session import get_db
# from app.services import user_service
#
# @router.get("/users")
# def list_users(db: Session = Depends(get_db)):
#     return user_service.list_users(db)
# ```
#
# در این مثال:
#
# - endpoint فقط مسئول دریافت درخواست و فراخوانی سرویس است.
# - وابستگی به دیتابیس صریحاً از طریق Depends بیان شده است.
# - در تست‌ها می‌توان `get_db` را override کرد و به‌جای دیتابیس واقعی، یک دیتابیس تست یا حتی یک mock تزریق کرد.
#
# اگر وابستگی‌ها را به‌صورت global و غیرقابل تزریق تعریف کنیم (برای مثال یک session دیتابیس global که همه‌جا مستقیم import شود)، در تست‌ها تقریباً هیچ امکان جایگزینی نداریم و رفتار سیستم به محیط واقعی بسته می‌شود؛ سناریویی که هرگونه تست جدی را دشوار و شکننده می‌کند.
#
# به‌طور خلاصه، استفاده‌ی درست از dependency injection در FastAPI پلی است بین معماری لایه‌ای و تست‌پذیری عملی پروژه.
#
# ---
#
# ## ۶. تست‌پذیری، لاگ‌گیری و مانیتورینگ
#
# تا اینجا دیدیم که ساختار پوشه‌ها، جداسازی لایه‌ها و مدیریت وابستگی‌ها چگونه به ساخت یک پروژه‌ی FastAPI مناسب production کمک می‌کنند. اما در محیط production، صرف کار کردن سیستم کافی نیست؛ باید بتوانیم صحت عملکرد آن را بسنجیم، رفتار آن را مشاهده کنیم و در صورت بروز خطا سریعاً واکنش نشان دهیم. اینجاست که تست، لاگ‌گیری و مانیتورینگ وارد صحنه می‌شوند.
#
# ### ۶.۱. تست‌ها
#
# پروژه‌ی بدون تست، در عمل در تاریکی توسعه می‌یابد. برای پوشش نیازهای production:
#
# - **تست واحد (Unit Tests)**
#   برای services و منطق اصلی. چون منطق کسب‌وکار از API و دیتابیس جدا شده، می‌توان آن را با ورودی‌های ساختگی به‌سادگی تست کرد.
#
# - **تست یکپارچه (Integration Tests)**
#   برای endpointها، معمولاً با استفاده از `TestClient` در FastAPI و یک دیتابیس تست. این تست‌ها قرارداد API و تعامل با لایه‌ی داده را بررسی می‌کنند.
#
# - **استفاده از pytest و ابزارهای کمکی**
#   pytest، به‌همراه fixtureها و ابزارهایی که خود FastAPI ارائه می‌دهد، فرایند تست را ساده و قابل اتکا می‌کند.
#
# بدون ساختار لایه‌ای و dependency injection، تست کردن سیستم به‌صورت جدی تقریباً غیرممکن یا بسیار پرهزینه می‌شود. این نکته نشان می‌دهد که توصیه‌های معماری پیشین مستقیماً به تست‌پذیری گره خورده‌اند.
#
# ### ۶.۲. لاگ‌گیری
#
# لاگ‌گیری در production، ابزار اصلی تشخیص و ردیابی مشکلات است. معمولاً:
#
# - یک ماژول مانند `core/logging.py` برای تنظیم logging تعریف می‌شود.
# - format لاگ‌ها، سطح آن‌ها (INFO, ERROR, DEBUG) و مقصدشان (فایل، stdout، سیستم جمع‌آوری لاگ) مشخص می‌شود.
# - لاگ‌ها به سیستم‌هایی مانند ELK، Loki یا Cloud Logging ارسال می‌شوند تا بتوان آن‌ها را جست‌وجو و تحلیل کرد.
#
# اگر لاگ‌گیری از ابتدا طراحی نشود، در مواجهه با یک خطای پیچیده، توسعه‌دهنده عملاً بدون سرنخ می‌ماند و بازتولید مشکل در محیط توسعه دشوار می‌شود.
#
# ### ۶.۳. مانیتورینگ و متریک‌ها
#
# مانیتورینگ به ما اجازه می‌دهد نه‌تنها رخدادهای خطا، بلکه روند کلی عملکرد سیستم را ببینیم:
#
# - جمع‌آوری متریک‌ها مانند تعداد درخواست‌ها، latency، نرخ خطا، و وضعیت منابع.
# - استفاده از ابزارهایی مانند Prometheus و Grafana یا سرویس‌های مشابه.
# - تعریف health-check endpoint برای بررسی وضعیت سرویس از بیرون (مثلاً توسط load balancer یا orchestrator).
#
# ترکیب تست، لاگ‌گیری و مانیتورینگ باعث می‌شود پروژه‌ی FastAPI در production نه‌تنها کار کند، بلکه قابل مشاهده و قابل اعتماد نیز باشد.
#
# ---
#
# ## ۷. امنیت، احراز هویت و مجوزها
#
# هیچ بحثی درباره‌ی «پروژه‌ی مناسب production» بدون پرداختن به امنیت کامل نیست. امنیت اگر به‌عنوان «افزونه» در انتهای کار دیده شود، معمولاً ناکامل و شکننده خواهد بود. بهتر است از ابتدا بخشی از طراحی باشد.
#
# ### ۷.۱. احراز هویت (Authentication)
#
# FastAPI از الگوهایی مانند OAuth2 با JWT به‌خوبی پشتیبانی می‌کند. می‌توان:
#
# - پیاده‌سازی مربوط به توکن‌ها و احراز هویت را در ماژول‌هایی مانند `core/security.py` یا `api/dependencies/auth.py` قرار داد.
# - در endpointها با استفاده از dependencyها، احراز هویت را اجباری یا اختیاری کرد.
#
# اگر احراز هویت در سطح endpointها پراکنده و بدون ساختار انجام شود (مثلاً هر endpoint جداگانه توکن را parse و validate کند)، احتمال بروز خطای امنیتی و ناسازگاری در رفتار بالا می‌رود.
#
# ### ۷.۲. مجوزها (Authorization)
#
# پس از احراز هویت، باید سطح دسترسی و نقش‌ها کنترل شوند:
#
# - تعریف Roleها و سیاست‌های دسترسی.
# - استفاده از dependencyها برای بررسی مجوزها در endpointها.
#
# این تفکیک بین authentication و authorization کمک می‌کند که سیاست‌های دسترسی به‌شکل متمرکز و قابل توسعه مدیریت شوند.
#
# ### ۷.۳. محافظت در برابر حملات رایج
#
# در محیط production، باید به مسائل عملی امنیت توجه شود:
#
# - محدود کردن اندازه‌ی درخواست‌ها برای جلوگیری از سوءاستفاده‌های مربوط به payloadهای بزرگ.
# - محافظت در برابر brute-force روی login، مثلاً با rate limiting.
# - استفاده از HTTPS در استقرار، تنظیم HSTS و headerهای امنیتی.
#
# طراحی امنیتی حساب‌شده، از تبدیل شدن پروژه به نقطه‌ی ضعف در معماری کلی سیستم جلوگیری می‌کند.
#
# ---
#
# ## ۸. استقرار (Deployment) و تنظیمات production
#
# تا اینجا بیشتر درباره‌ی «داخل» پروژه صحبت کردیم. برای پاسخ کامل به پرسش «چگونه یک پروژه‌ی FastAPI مناسب production داشته باشیم؟»، باید ببینیم این پروژه چگونه در محیط عملیاتی اجرا می‌شود.
#
# ### ۸.۱. استفاده از Uvicorn/Gunicorn
#
# برای استقرار FastAPI در production، معمولاً از ترکیب Gunicorn + Uvicorn worker استفاده می‌شود:
#
# ```bash
# gunicorn -k uvicorn.workers.UvicornWorker app.main:app
# ```
#
# این رویکرد امکان مدیریت فرآیندها، استفاده از چند worker و تنظیمات پیشرفته‌ی سطح وب‌سرور را فراهم می‌کند؛ چیزی که اجرای ساده‌ی `uvicorn main:app` به‌تنهایی ارائه نمی‌دهد.
#
# ### ۸.۲. Containerization با Docker
#
# قرار دادن اپلیکیشن در کانتینر، آن را مستقل از محیط زیرین می‌کند:
#
# - ساخت Dockerfile که در آن dependencyها در مرحله‌ی build نصب شوند.
# - استفاده از imageهای slim و امن برای کاهش سطح حمله و اندازه‌ی image.
# - استفاده از docker-compose برای مدیریت سرویس‌های وابسته (دیتابیس، کش، صف‌ها).
#
# اگر کانتینرها درست طراحی نشوند (مثلاً همه‌چیز در یک image سنگین و نامنسجم قرار گیرد)، استقرار و مقیاس‌بندی در آینده به‌مراتب پیچیده‌تر می‌شود.
#
# ### ۸.۳. Reverse proxy و مقیاس‌پذیری
#
# در محیط‌های جدی، معمولاً:
#
# - یک reverse proxy مانند Nginx برای مدیریت requestها، TLS termination و load balancing استفاده می‌شود.
# - پروژه برای اجرا در چند replica آماده می‌شود؛ به‌این معنا که stateهای حساس یا در سیستم‌های مشترکی مانند Redis نگه‌داری می‌شوند یا به‌کلی از stateful بودن پرهیز می‌شود.
#
# این نکات استقرار نشان می‌دهند که پروژه‌ی FastAPI اگرچه از نظر کد تمیز است، باید با معماری عملیاتی محیط نیز سازگار باشد تا در مقیاس بالا پاسخ‌گو باشد.
#
# ---
#
# ## ۹. مستندسازی و قراردادها
#
# FastAPI به‌صورت خودکار مستندات OpenAPI تولید می‌کند؛ قابلیتی بسیار مفید، اما کافی نیست. در پروژه‌ی production، مستندسازی و مدیریت قراردادها (API contracts) برای همکاری بین تیم‌ها حیاتی است.
#
# - تعریف schemaها باید دقیق و دارای توضیحات مناسب باشد تا کلاینت‌ها، رفتار API را به‌درستی درک کنند.
# - نسخه‌بندی APIها مهم است؛ مثلاً `/api/v1` و `/api/v2`. این کار کمک می‌کند تغییرات بزرگ بدون شکستن سرویس‌های موجود اعمال شوند.
# - قراردادها بین تیم‌های فرانت‌اند و سایر مصرف‌کنندگان API بهتر است به‌صورت رسمی، نسخه‌دار و قابل ردیابی مدیریت شوند.
#
# اگر قراردادها غیررسمی و پراکنده باشند، هر تغییر در API ممکن است یک کلاینت را ناخواسته خراب کند. مستندسازی درست، جلوی این نوع شکست را می‌گیرد و تعامل بین تیم‌ها را قابل اعتماد می‌سازد.
#
# ---
#
# ## نتیجه‌گیری و گام‌های عملی
#
# برای داشتن یک پروژه‌ی FastAPI ساختار یافته و ماژولار مناسب محیط production، کافی نیست که صرفاً چند endpoint سریع و کارآمد بنویسیم. آنچه در محیط عملیاتی اهمیت دارد، قابلیت نگه‌داری، توسعه و اعتماد به سیستم در طول زمان است. آنچه در این نوشته مرور شد، مجموعه‌ای از اصول و الگوهاست که اگر از ابتدا در طراحی لحاظ شوند، احتمال تبدیل شدن پروژه به «کد اسپاگتی» و سیستم شکننده را به‌طور جدی کاهش می‌دهند.
#
# خلاصه‌ی پیام‌ها:
#
# - ساختار پوشه‌ی منطقی و جداسازی لایه‌ها (API، منطق کسب‌وکار، لایه‌ی داده)، پایه‌ی اصلی معماری تمیز در FastAPI است.
# - مدیریت حرفه‌ای تنظیمات، dependency injection و تفکیک محیط‌ها، پروژه را از خطاهای رایج کانفیگ و وابستگی‌های سخت نجات می‌دهد.
# - توجه به تست‌پذیری، لاگ‌گیری و مانیتورینگ، پروژه را از حالت «جعبه‌ی سیاه» خارج کرده و آن را به سیستمی قابل مشاهده و قابل اعتماد تبدیل می‌کند.
# - امنیت و استقرار، اگر از ابتدا در طراحی لحاظ شوند، مانع از آن می‌شوند که پروژه‌ی FastAPI در منظومه‌ی کلی سیستم به نقطه‌ی ضعف تبدیل شود.
#
# برای تیمی که می‌خواهد از صفر یک پروژه‌ی FastAPI مناسب production بسازد، می‌توان یک مسیر عملی کوتاه پیشنهاد کرد:
#
# 1. **در آغاز پروژه، ساختار دایرکتوری و جداسازی لایه‌ها را تعریف کنید**
#    پوشه‌های core، api، models، schemas، services، db و tests را مشخص و اولین نسخه‌ی ساده‌ی آن‌ها را ایجاد کنید.
#
# 2. **از همان ابتدا تنظیمات و dependency injection را طراحی کنید**
#    یک کلاس Settings مبتنی بر Pydantic بسازید، متغیرهای محیطی را تعریف کنید، و وابستگی‌ها (مانند `get_db`) را به‌صورت dependency پیاده‌سازی کنید.
#
# 3. **منطق کسب‌وکار را در services قرار دهید و برای آن تست واحد بنویسید**
#    endpointها را تا حد ممکن نازک نگه دارید و هر تغییر در منطق را ابتدا در سرویس‌ها و تست‌ها اعمال و بررسی کنید.
#
# 4. **قبل از ورود به production، لاگ‌گیری، مانیتورینگ، امنیت پایه و استقرار کانتینری را راه‌اندازی کنید**
#    یک مسیر استقرار (مثلاً Docker + Gunicorn/Uvicorn + Nginx) طراحی و تست کنید و حداقل متریک‌ها و health-check را اضافه کنید.
#
# با پایبندی به این گام‌ها و اصول، می‌توان پروژه‌ای FastAPI ساخت که نه‌تنها در محیط توسعه خوش‌دست است، بلکه در محیط production نیز قابل اتکا، قابل توسعه و آماده‌ی رشد در کنار نیازهای کسب‌وکار باقی بماند.

# %% [markdown]
# To better visualize the output of each step in the reflective writing workflow, we use a utility function called `show_output`. This function displays the results of each stage (drafting, reflection, and revision) in styled boxes with custom background and text colors, making it easier to compare and understand the progression of the essay.

# %%
from utils.utils import show_output


show_output("مرحله اول: پیش‌نویس", draft, background="#fff8dc", text_color="#333333")
show_output("مرحله دوم – Reflection", feedback, background="#e0f7fa", text_color="#222222")
show_output("مرحله سوم – بازنگری یا Revision", revised, background="#f3e5f5", text_color="#222222")
# Out:
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #fff8dc;
#         color: #333333;
#         direction: rtl;
#         text-align: right;
#     ">
#         <h3 style="
#             margin-top: 0;
#             font-family: Vazirmatn, Vazir, Tahoma, Arial;
#             font-weight: bold;
#         ">مرحله اول: پیش‌نویس</h3>
#         <div style="
#             white-space: pre-wrap;
#             font-family: Vazirmatn, Vazir, Tahoma, monospace;
#             font-size: 14px;
#             line-height: 1.8;
#         ">در این نوشته به پرسش «چگونه یک پروژه FastAPI ساختار یافته و ماژولار مناسب محیط production داشته باشیم؟» پاسخ می‌دهیم. هدف، ارائه‌ی یک دید کلی و عملی برای طراحی، سازمان‌دهی و آماده‌سازی پروژه‌ای است که نه‌تنها در محیط توسعه (development) کار کند، بلکه در مقیاس بزرگ‌تر و با الزامات جدی‌تر production نیز قابل اتکا، قابل نگه‌داری و قابل توسعه باشد. برای این منظور، ابتدا به اهمیت ساختار و ماژولار بودن پروژه می‌پردازیم، سپس الگوی‌های رایج ساختاردهی، مدیریت تنظیمات، جداسازی لایه‌ها، تست‌پذیری، امنیت و استقرار را مرور می‌کنیم و در پایان نکاتی جمع‌بندی می‌گردد که به‌عنوان چک‌لیست عملی قابل استفاده است.
#
# ---
#
# <h4 style="font-weight: bold; font-size: 1.3em; margin: 12px 0 6px 0;">مقدمه</h4>
#
# FastAPI به‌دلیل سادگی، کارایی بالا و پشتیبانی خوب از تایپ‌ها و async، انتخاب محبوبی برای ساخت APIهای مدرن است. با این حال، بسیاری از نمونه‌کدها و آموزش‌ها، روی پروژه‌های کوچک و ساده تمرکز دارند؛ پروژه‌هایی که یک فایل main.py دارند و چند endpoint ساده. در محیط production، چنین رویکردی خیلی زود تبدیل به کدی پیچیده، سخت‌فهم و شکننده می‌شود.
#
# برای داشتن یک پروژه‌ی FastAPI مناسب production، لازم است از ابتدا به چند اصل کلیدی توجه شود:
#
# - <strong style="font-weight: bold;">ساختار دایرکتوری‌ها و ماژول‌ها</strong> روشن و قابل فهم باشد.
# - <strong style="font-weight: bold;">جداسازی لایه‌ها</strong> (presentation، business، data) رعایت شود.
# - <strong style="font-weight: bold;">مدیریت تنظیمات و کانفیگ</strong> امن، قابل نسخه‌گذاری و قابل تغییر باشد.
# - <strong style="font-weight: bold;">قابلیت تست، لاگ‌گیری و مانیتورینگ</strong> از ابتدا در نظر گرفته شود.
# - <strong style="font-weight: bold;">مسائل امنیتی و استقرار</strong> در طراحی اولیه‌ی پروژه لحاظ شوند.
#
# در ادامه، این اصول را به‌صورت منظم بررسی می‌کنیم.
#
# ---
#
# <h4 style="font-weight: bold; font-size: 1.3em; margin: 12px 0 6px 0;">بدنه</h4>
#
# <h5 style="font-weight: bold; font-size: 1.1em; margin: 10px 0 5px 0;">۱. اهمیت ساختار و ماژولار بودن در پروژه‌های FastAPI</h5>
#
# در پروژه‌های کوچک، عموماً همه‌چیز در چند فایل محدود جمع می‌شود: modelها، routeها، dependencyها و تنظیمات. این حالت برای یادگیری مناسب است، اما در production:
#
# - تیم‌های مختلف باید روی بخش‌های مختلف کار کنند.
# - نیاز به تست واحد، تست یکپارچه و CI/CD داریم.
# - تغییرات مداوم در کسب‌وکار و نیازمندی‌ها رخ می‌دهد.
#
# اگر پروژه ساختار نداشته باشد، هر تغییر کوچک زمان‌بر می‌شود و احتمال بروز خطا بالا می‌رود. ساختار ماژولار کمک می‌کند:
#
# - هر ماژول وظیفه‌ی مشخصی داشته باشد (اصل Single Responsibility).
# - کد قابل‌استفاده‌ی مجدد باشد.
# - وابستگی‌ها کنترل شوند و از coupling شدید جلوگیری شود.
#
# بنابراین، طراحی ساختار پروژه از همان ابتدا یک سرمایه‌گذاری بلندمدت است.
#
# ---
#
# <h5 style="font-weight: bold; font-size: 1.1em; margin: 10px 0 5px 0;">۲. نمونه‌ای از ساختار پوشه‌ها در یک پروژه‌ی production</h5>
#
# الگوی واحد و استانداردی وجود ندارد، اما بعضی ساختارها رایج و اثبات‌شده هستند. یک نمونه‌ی ساده، اما قابل توسعه، می‌تواند چنین باشد:
#
# ```bash
# app/
#     core/
#         config.py
#         security.py
#         logging.py
#     api/
#         v1/
#             endpoints/
#                 users.py
#                 items.py
#             dependencies/
#                 auth.py
#                 db.py
#     models/
#         user.py
#         item.py
#     schemas/
#         user.py
#         item.py
#     services/
#         user_service.py
#         item_service.py
#     db/
#         base.py
#         session.py
#         migrations/   # مثلا برای Alembic
#     tests/
#         api/
#         services/
#         ...
#     main.py
# ```
#
# در این ساختار:
#
# - <strong style="font-weight: bold;">core/</strong> شامل تنظیمات و اجزای عمومی سیستم است.
# - <strong style="font-weight: bold;">api/</strong> شامل لایه‌ی ارائه (routes، dependencies) است.
# - <strong style="font-weight: bold;">models/</strong> برای مدل‌های دیتابیس (ORM، مثلاً SQLAlchemy).
# - <strong style="font-weight: bold;">schemas/</strong> برای Pydantic مدل‌ها (ورودی/خروجی API).
# - <strong style="font-weight: bold;">services/</strong> شامل منطق تجاری است؛ لایه‌ای بین api و db.
# - <strong style="font-weight: bold;">db/</strong> برای مدیریت اتصال، session، migrationها.
# - <strong style="font-weight: bold;">tests/</strong> برای تست‌ها.
#
# این ساختار به تفکیک نقش‌ها کمک می‌کند. برای مثال، تغییر در مدل دیتابیس الزاماً به تغییر در endpointها منجر نمی‌شود؛ چون schema و service به‌عنوان لایه‌های میانی عمل می‌کنند.
#
# ---
#
# <h5 style="font-weight: bold; font-size: 1.1em; margin: 10px 0 5px 0;">۳. مدیریت تنظیمات (Configuration Management)</h5>
#
# در محیط production، تنظیمات و کانفیگ‌ها بسیار مهم هستند: آدرس دیتابیس، کلیدهای API، سطوح لاگ، تنظیمات امنیتی و… نباید به‌صورت هاردکد در کد قرار گیرند.
#
# بهترین الگوها:
#
# 1. <strong style="font-weight: bold;">استفاده از متغیرهای محیطی (Environment Variables):</strong>
#    - در Docker، Kubernetes یا هر سیستم استقرار دیگری، متغیرهای محیطی روش اصلی تنظیمات هستند.
#    - مثلاً: `DATABASE_URL`, `SECRET_KEY`, `ENV=production`.
#
# 2. <strong style="font-weight: bold;">استفاده از Pydantic Settings:</strong>
#    - FastAPI به‌خوبی با Pydantic سازگار است و می‌توان یک کلاس تنظیمات ساخت:
#      ```python
#      from pydantic import BaseSettings
#
#      class Settings(BaseSettings):
#          database_url: str
#          secret_key: str
#          debug: bool = False
#
#          class Config:
#              env_file = ".env"
#      ```
#
# 3. <strong style="font-weight: bold;">تفکیک تنظیمات برای محیط‌های مختلف:</strong>
#    - development، staging، production می‌توانند فایل‌های env متفاوت داشته باشند.
#    - لازم است در CI/CD مشخص شود کدام تنظیمات کجا استفاده می‌شود.
#
# 4. <strong style="font-weight: bold;">امنیت تنظیمات:</strong>
#    - فایل‌های `.env` حاوی secrets نباید در مخزن عمومی قرار گیرند.
#    - استفاده از vaultها (مثل HashiCorp Vault یا secret managerهای cloud) در پروژه‌های جدی توصیه می‌شود.
#
# ---
#
# <h5 style="font-weight: bold; font-size: 1.1em; margin: 10px 0 5px 0;">۴. جداسازی لایه‌ها: API، منطق کسب‌وکار، داده</h5>
#
# برای ساختار ماژولار، جداسازی لایه‌ها کلیدی است:
#
# 1. <strong style="font-weight: bold;">لایه‌ی API (Presentation Layer):</strong>
#    - شامل endpointها، مسیرها، dependencyها برای احراز هویت، pagination، و غیره.
#    - فقط مسئول دریافت درخواست، اعتبارسنجی اولیه و انتقال داده به لایه‌ی منطق است.
#
# 2. <strong style="font-weight: bold;">لایه‌ی منطق کسب‌وکار (Service Layer):</strong>
#    - تابع‌ها یا کلاس‌هایی که عملیات اصلی کسب‌وکار را انجام می‌دهند، مثل:
#      - ثبت کاربر جدید
#      - اعمال قوانین تخفیف
#      - مدیریت سفارش‌ها
#    - این لایه باید تا حد ممکن از جزئیات API و دیتابیس مستقل باشد.
#
# 3. <strong style="font-weight: bold;">لایه‌ی داده (Data Access Layer):</strong>
#    - با دیتابیس یا سایر سیستم‌های ذخیره‌سازی ارتباط دارد.
#    - شامل مدل‌های ORM، repositoryها و کار با session.
#
# این جداسازی باعث می‌شود:
#
# - بتوان منطق را بدون تغییر در API تست کرد.
# - تغییر دیتابیس یا روش ذخیره‌سازی تأثیر کمتری روی سایر بخش‌ها داشته باشد.
# - از تداخل concerns جلوگیری شود.
#
# ---
#
# <h5 style="font-weight: bold; font-size: 1.1em; margin: 10px 0 5px 0;">۵. dependency injection و مدیریت وابستگی‌ها</h5>
#
# FastAPI به‌صورت داخلی از dependency injection پشتیبانی می‌کند. استفاده‌ی درست از این قابلیت در پروژه‌ی production بسیار مفید است:
#
# - می‌توان اتصال دیتابیس، سرویس‌های خارجی، و حتی سرویس‌های داخلی را به‌عنوان dependency تعریف کرد.
# - در تست‌ها، این dependencyها را mock یا override کرد.
#
# برای مثال، مدیریت session دیتابیس:
#
# ```python
# from fastapi import Depends
# from sqlalchemy.orm import Session
# from app.db.session import get_db
#
# @router.get("/users")
# def list_users(db: Session = Depends(get_db)):
#     return user_service.list_users(db)
# ```
#
# این رویکرد:
#
# - کد را
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #e0f7fa;
#         color: #222222;
#         direction: rtl;
#         text-align: right;
#     ">
#         <h3 style="
#             margin-top: 0;
#             font-family: Vazirmatn, Vazir, Tahoma, Arial;
#             font-weight: bold;
#         ">مرحله دوم – Reflection</h3>
#         <div style="
#             white-space: pre-wrap;
#             font-family: Vazirmatn, Vazir, Tahoma, monospace;
#             font-size: 14px;
#             line-height: 1.8;
#         ">این متن از نظر محتوا غنی، منظم و نسبتاً کامل است؛ اما برای تبدیل شدن به یک مقاله قوی‌تر و خواندنی‌تر در چند سطح می‌توان آن را بهبود داد:
#
# از نظر ساختار کلی، مقاله به‌خوبی از مقدمه–بدنه–نتیجه‌گیری پیروی می‌کند و سرفصل‌ها منطقی چیده شده‌اند. با این حال، بدنه کمی «فهرست‌محور» است؛ هر بخش بیشتر شبیه راهنمای نکته‌ای است تا یک بحث تحلیلی. می‌توان در ابتدای هر بخش یک یا دو جمله‌ی گذار اضافه کرد که نشان دهد چرا این بخش در پاسخ به پرسش اصلی ضروری است و چگونه به بخش قبل و بعد مرتبط می‌شود. مثلاً در بخش «مدیریت تنظیمات» قبل از ورود به لیست، یک مثال کوتاه از یک کانفیگ بد در فضای production و پیامدهایش، هم زمینه می‌سازد و هم خواننده را درگیر می‌کند. همچنین، شاید بهتر باشد بخش‌ها کمی ادغام یا اولویت‌بندی شوند؛ مثلاً «dependency injection» را می‌توان زیرمجموعه‌ی «جداسازی لایه‌ها و تست‌پذیری» آورد تا ساختار مقاله کمتر پراکنده و بیشتر موضوع‌محور باشد.
#
# از نظر وضوح، زبان متن عمدتاً روان و استاندارد است، اما در برخی جاها جملات طولانی و چندلایه هستند که خواننده‌ی متوسط را خسته می‌کنند. کوتاه‌تر کردن بعضی جملات و پرهیز از تکرارهای معنایی (مثل «قابل اتکا، قابل نگه‌داری و قابل توسعه» که می‌توان برای تنوع در جاهای مختلف به‌صورت متفاوت بیان‌شان کرد) به خوانایی کمک می‌کند. ترکیب انگلیسی–فارسی در واژگان فنی (production، development، service layer، config) طبیعتاً اجتناب‌ناپذیر است، اما بهتر است یک‌رسانه باشد: یا معادل فارسی ثابت و یک‌دست (مثلاً «محیط عملیاتی» برای production) یا اگر ترجیح می‌دهید انگلیسی را حفظ کنید، در اولین اشاره، معادل فارسی را بیاورید و بعداً فقط یکی را استفاده کنید. همچنین، در بخش‌هایی مثل ساختار پوشه‌ها، توضیح مختصر روی برخی پوشه‌ها (مثلاً تفاوت دقیق models و schemas) می‌تواند از ابهام برای خواننده‌ی کمتر آشنا جلوگیری کند.
#
# از نظر قوت استدلال، مقاله بیشتر «راهنمای خوب‌عمل‌کردن» است تا یک متن کاملاً «استدلالی». یعنی پیشنهادها درست‌اند، اما کمتر نشان می‌دهد که «اگر این کار را نکنید چه می‌شود» یا «چرا این رویکرد از رویکردهای دیگر بهتر است». برای تقویت بعد انتقادی و استدلالی، می‌توانید از چند ضدنمونه استفاده کنید: مثلاً توضیح دهید پروژه‌ای که همه‌چیز را در یک فایل نگه می‌دارد هنگام افزودن ویژگی‌های جدید چه مشکلات مشخصی در تست و نگه‌داری پیدا می‌کند؛ یا اینکه عدم تفکیک لایه‌ها چگونه باعث coupling شدید و سخت شدن جایگزینی دیتابیس می‌شود. بیان این «سناریوهای شکست» حتی به شکل کوتاه، به خواننده نشان می‌دهد که توصیه‌ها صرفاً «بهتر» نیستند، بلکه جلوی مشکلات واقعی را می‌گیرند. همچنین، تا حدی می‌توانید به بحث‌های عمومی‌تر معماری اشاره کنید (مثل مقایسه مختصر با معماری‌های monolith تمیز یا microservices) تا جایگاه این ساختار پیشنهاد شده در منظومه‌ی بزرگ‌تر معماری نرم‌افزار روشن‌تر شود.
#
# از نظر سبک و لحن، متن حرفه‌ای، آموزشی و به‌نسبت بی‌طرف است، اما می‌تواند کمی جذاب‌تر شود. در حال حاضر، تقریباً همه‌جا از لحن توضیحی–دستوری («بهترین الگوها:»، «لازم است…») استفاده کرده‌اید. اگر گه‌گاهی لحن را از «باید» به «می‌توانید» و از «دستور» به «تجربه» تغییر دهید (مثلاً اضافه کردن جملاتی از جنس «در تجربه‌ی بسیاری از تیم‌ها…» یا «در عمل دیده می‌شود که…»)، صدا و شخصیت نویسنده بیشتر به چشم می‌آید. همچنین، می‌توانید در پایان بعضی بخش‌ها یک «جمع‌بندی کوچک» یک‌جمله‌ای بگذارید که پیام کلیدی را برجسته کند؛ این کار مخصوصاً در بخش‌های طولانی مثل تست و لاگ‌گیری مفید است.
#
# در سطح جزئی‌تر، چند نکته‌ی سبک‌شناسانه وجود دارد: ابتدا و انتهای متن به‌خوبی به سؤال اصلی ارجاع می‌دهند، اما در بخش‌های میانی کمتر به خود «پرسش» بازمی‌گردید. می‌توانید وسط مقاله یک بار دیگر صراحتاً یادآوری کنید که تمام این بحث‌ها در پاسخ به پرسش «چگونه…» است و مثلاً بگویید «تا اینجا دیدیم که ساختار پوشه‌ها و جداسازی لایه‌ها چگونه به تولید یک پروژه‌ی مناسب production کمک می‌کنند؛ حالا به تنظیمات و امنیت می‌پردازیم که دو ستون دیگر این هدف هستند». این نوع ارجاع دوره‌ای انسجام کلی متن را تقویت می‌کند. همچنین، نتیجه‌گیری اگرچه شسته‌رفته است، می‌تواند کمی عملی‌تر شود؛ مثلاً به‌جای یک جمع‌بندی صرفاً مفهومی، یک «گام‌های پیشنهادی» خیلی کوتاه (۳–۴ قدم) برای تیمی که می‌خواهد از صفر شروع کند ارائه کنید تا خواننده احساس کند پس از خواندن متن، می‌داند از کجا شروع کند.
#
# در مجموع، مقاله از نظر محتوا و نظم بسیار خوب است و عمده‌ی نکات مهم برای یک پروژه‌ی FastAPI در محیط production را پوشش می‌دهد. تقویت پیوند بین بخش‌ها، افزودن کمی استدلال و مثال منفی، ساده‌سازی برخی جملات و دادن یک مسیر عملی در نتیجه‌گیری، می‌تواند آن را از یک «چک‌لیست توصیفی» به یک متن راهبردی و اثرگذارتر تبدیل کند.</div>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #f3e5f5;
#         color: #222222;
#         direction: rtl;
#         text-align: right;
#     ">
#         <h3 style="
#             margin-top: 0;
#             font-family: Vazirmatn, Vazir, Tahoma, Arial;
#             font-weight: bold;
#         ">مرحله سوم – بازنگری یا Revision</h3>
#         <div style="
#             white-space: pre-wrap;
#             font-family: Vazirmatn, Vazir, Tahoma, monospace;
#             font-size: 14px;
#             line-height: 1.8;
#         ">در این نوشته به پرسش «چگونه یک پروژه‌ی FastAPI ساختار یافته و ماژولار مناسب محیط production داشته باشیم؟» پاسخ می‌دهیم. هدف، ارائه‌ی یک دید کلی و عملی برای طراحی، سازمان‌دهی و آماده‌سازی پروژه‌ای است که نه‌تنها در محیط توسعه (development) قابل استفاده باشد، بلکه در مقیاس بزرگ‌تر و با الزامات جدی‌تر محیط عملیاتی (production) نیز پایدار، قابل نگه‌داری و قابل توسعه باقی بماند.
#
# برای رسیدن به این هدف، لازم است از ابتدا به چند اصل کلیدی توجه شود: ساختار روشن دایرکتوری‌ها و ماژول‌ها، جداسازی لایه‌ها، مدیریت حرفه‌ای تنظیمات، قابلیت تست و مشاهده‌پذیری (لاگ‌گیری و مانیتورینگ)، و در نهایت امنیت و نحوه‌ی استقرار. در ادامه، با نگاهی یکپارچه به این اصول، نشان می‌دهیم که چگونه می‌توان یک پروژه‌ی FastAPI را از حالت «نمونه‌کد آموزشی» به یک سرویس عملیاتی قابل اتکا ارتقا داد.
#
# ---
#
# <h4 style="font-weight: bold; font-size: 1.3em; margin: 12px 0 6px 0;">مقدمه</h4>
#
# FastAPI به‌دلیل سادگی، کارایی بالا و پشتیبانی خوب از تایپ‌ها و async، انتخاب محبوبی برای ساخت APIهای مدرن است. بسیاری از نمونه‌کدها و آموزش‌ها، حول پروژه‌های کوچک شکل گرفته‌اند: یک فایل main.py، چند endpoint ساده و شاید یک مدل دیتابیس. این مثال‌ها برای شروع و یادگیری عالی‌اند، اما اگر همان الگو را بدون تغییر وارد production کنیم، خیلی زود با سیستمی مواجه می‌شویم که هر تغییر کوچک در آن پرهزینه و پرریسک است.
#
# در محیط production:
#
# - تیم‌های مختلف روی بخش‌های مختلف سیستم کار می‌کنند.
# - تغییرات کسب‌وکار مداوم است و باید سریع و ایمن اعمال شود.
# - نیاز به تست، لاگ‌گیری، مانیتورینگ و استقرار خودکار جدی است.
#
# اگر پروژه بدون ساختار و ماژول‌بندی مناسب رشد کند، به‌سمت «کد اسپاگتی» می‌رود؛ جایی که افزودن یک ویژگی ساده، ممکن است چندین نقطه‌ی ظریف و شکننده را تحت تأثیر قرار دهد. برای جلوگیری از این سناریوی شکست، در ادامه به‌صورت گام‌به‌گام بررسی می‌کنیم که یک پروژه‌ی FastAPI مناسب محیط production چه ویژگی‌هایی دارد و چگونه می‌توان از ابتدا این ویژگی‌ها را در طراحی لحاظ کرد.
#
# ---
#
# <h4 style="font-weight: bold; font-size: 1.3em; margin: 12px 0 6px 0;">۱. چرا ساختار و ماژولار بودن در FastAPI حیاتی است؟</h4>
#
# نقطه‌ی شروع پاسخ به پرسش اصلی، مسئله‌ی ساختار است. اگر ساختار پروژه از ابتدا روشن و ماژولار نباشد، سایر تلاش‌ها (تست، امنیت، استقرار) روی پایه‌ای لرزان بنا می‌شوند.
#
# در پروژه‌های کوچک، معمولاً همه‌چیز در چند فایل محدود قرار می‌گیرد: مدل‌ها، routeها، dependencyها و تنظیمات. این روش برای یادگیری مناسب است، اما در پروژه‌های جدی، پیامدهای آن کاملاً مشهود است. برای مثال، اگر همه‌ی کدها در main.py باشند:
#
# - اضافه کردن یک endpoint جدید، نیازمند جست‌وجوی طولانی در فایل و درک روابط متداخل است.
# - تست کردن منطق کسب‌وکار بدون بالا آوردن کل اپلیکیشن تقریباً ناممکن می‌شود.
# - هر تغییر در دیتابیس، مستقیماً روی endpointها اثر می‌گذارد و ریسک شکست backward compatibility را بالا می‌برد.
#
# در مقابل، ساختار ماژولار کمک می‌کند:
#
# - هر بخش وظیفه‌ی مشخصی داشته باشد (اصل Single Responsibility).
# - کد قابل استفاده‌ی مجدد شود و تکرارهای بیهوده کاهش یابد.
# - وابستگی‌ها کنترل شوند و از coupling شدید بین لایه‌ها جلوگیری شود.
#
# به‌عبارت دیگر، طراحی ساختار پروژه در ابتدای کار یک هزینه‌ی کوچک است که در میان‌مدت و بلندمدت، بهره‌ی بزرگی در نگه‌داری و توسعه بازمی‌گرداند.
#
# ---
#
# <h4 style="font-weight: bold; font-size: 1.3em; margin: 12px 0 6px 0;">۲. نمونه‌ای از ساختار پوشه‌ها در یک پروژه‌ی production</h4>
#
# پس از روشن شدن اهمیت ساختار، طبیعی است به این پرسش برسیم که «این ساختار در عمل چه شکلی دارد؟». الگوی واحد و مطلقی وجود ندارد، اما الگوهای رایج و آزموده‌شده می‌توانند نقطه‌ی شروع خوبی باشند. یک نمونه‌ی ساده اما قابل توسعه، می‌تواند چنین باشد:
#
# ```bash
# app/
#     core/
#         config.py
#         security.py
#         logging.py
#     api/
#         v1/
#             endpoints/
#                 users.py
#                 items.py
#             dependencies/
#                 auth.py
#                 db.py
#     models/
#         user.py
#         item.py
#     schemas/
#         user.py
#         item.py
#     services/
#         user_service.py
#         item_service.py
#     db/
#         base.py
#         session.py
#         migrations/   # مثلا برای Alembic
#     tests/
#         api/
#         services/
#         ...
#     main.py
# ```
#
# در این ساختار:
#
# - <strong style="font-weight: bold;">core/</strong>
#   شامل تنظیمات و اجزای عمومی سیستم است: مدیریت کانفیگ، امنیت پایه، و راه‌اندازی logging. این پوشه جای «زیرساخت» اپلیکیشن است.
#
# - <strong style="font-weight: bold;">api/</strong>
#   لایه‌ی ارائه (Presentation Layer) را در بر می‌گیرد: routeها، endpointها و dependencyهای مربوط به احراز هویت، اتصال به دیتابیس و سایر وابستگی‌های سطح HTTP. برای مثال، `api/v1/endpoints/users.py` فقط مسئول تعریف مسیرها و فراخوانی سرویس‌های مربوطه است.
#
# - <strong style="font-weight: bold;">models/</strong>
#   مدل‌های دیتابیس (مثلاً SQLAlchemy) در این پوشه قرار می‌گیرند؛ چیزی که واقعاً روی جدول‌ها و روابط در دیتابیس نگاشت می‌شود.
#
# - <strong style="font-weight: bold;">schemas/</strong>
#   مدل‌های Pydantic برای ورودی/خروجی API در اینجا تعریف می‌شوند. تفاوت مهم با models این است که schemas نمای بیرونی داده را برای API مشخص می‌کنند (مثلاً چه فیلدهایی به کلاینت نشان داده شوند)، در حالی که models ساختار داده را در سطح ذخیره‌سازی تعیین می‌کنند. این تفکیک اجازه می‌دهد تغییرات دیتابیس لزوماً به تغییر قرارداد API منجر نشود.
#
# - <strong style="font-weight: bold;">services/</strong>
#   لایه‌ی منطق کسب‌وکار (Service Layer). عملیات اصلی مانند ثبت کاربر جدید، اعمال قوانین تخفیف یا مدیریت سفارش‌ها در اینجا پیاده‌سازی می‌شود. این لایه بین api و db قرار می‌گیرد و تا حد امکان از جزئیات HTTP و ذخیره‌سازی مستقل است.
#
# - <strong style="font-weight: bold;">db/</strong>
#   برای مدیریت اتصال به دیتابیس، session، و migrationها. مثلاً `session.py` تابعی برای تولید Session و `migrations/` اسکریپت‌های Alembic را در خود دارد.
#
# - <strong style="font-weight: bold;">tests/</strong>
#   ساختار تست‌ها را منعکس می‌کند: تست endpointها، تست سرویس‌ها و… هرچه ساختار اپلیکیشن تمیزتر باشد، ساختن تست‌های هم‌ساختار آسان‌تر می‌شود.
#
# این ساختار به تفکیک نقش‌ها کمک می‌کند. برای مثال، اگر نیاز باشد فیلد جدیدی به جدول user اضافه شود، ابتدا مدل دیتابیس در `models/user.py` به‌روزرسانی می‌شود، سپس schema مربوط در `schemas/user.py` و در نهایت سرویس‌ها در `services/user_service.py`. endpointها فقط در صورتی تغییر می‌کنند که قرارداد API تغییر کند. نتیجه این است که وابستگی‌ها شفاف و قابل کنترل می‌مانند.
#
# تا اینجا دیدیم که صرفاً با تعریف یک ساختار پوشه‌ی منطقی و جداسازی لایه‌ها، قدم بزرگی به‌سمت پاسخ به پرسش «چگونه یک پروژه‌ی FastAPI مناسب production داشته باشیم؟» برداشته‌ایم. در ادامه، به ستون‌های دیگری می‌پردازیم که این ساختار را عملی و ایمن می‌کنند.
#
# ---
#
# <h4 style="font-weight: bold; font-size: 1.3em; margin: 12px 0 6px 0;">۳. مدیریت تنظیمات (Configuration Management)</h4>
#
# ساختار خوب بدون مدیریت حرفه‌ای تنظیمات، در production به‌سرعت با مشکلات عملی روبه‌رو می‌شود. یک مثال رایج، هاردکد کردن آدرس دیتابیس یا کلیدهای امنیتی در کد است. در چنین حالتی، تغییر محیط از development به staging یا production نیازمند تغییر مستقیم در کد است؛ کاری که هم پرریسک است و هم در فرایند CI/CD خوب جا نمی‌گیرد.
#
# برای پرهیز از این وضعیت و فراهم کردن انعطاف لازم، چند الگو متداول و مؤثر وجود دارد:
#
# 1. <strong style="font-weight: bold;">استفاده از متغیرهای محیطی (Environment Variables)</strong>
#    در اغلب سیستم‌های استقرار (Docker، Kubernetes، سرویس‌های ابری)، تنظیمات از طریق متغیرهای محیطی مدیریت می‌شوند. مثلاً:
#
#    - `DATABASE_URL`
#    - `SECRET_KEY`
#    - `ENV=production`
#
#    این رویکرد اجازه می‌دهد که همان کد در محیط‌های مختلف با تنظیمات متفاوت اجرا شود، بدون آن‌که نیازی به تغییر در مخزن کد باشد.
#
# 2. <strong style="font-weight: bold;">استفاده از Pydantic Settings</strong>
#    FastAPI با Pydantic سازگار ا
